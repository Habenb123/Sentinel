# %%
import cv2
import numpy as np
from tensorflow.keras.models import load_model

# %%
image_model = load_model("nsfw_mobilenet_model.keras")
classes = ['drawings', 'hentai', 'neutral', 'porn', 'sexy']

def check_image(img_path):
    
    img = cv2.imread(img_path)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    img = cv2.resize(img, (224, 224))
    
    img = img.astype(np.float32) / 255.0
    
    img = np.expand_dims(img, axis=0)

    pred = image_model.predict(img)[0]
    label = np.argmax(pred)
    class_name = classes[label]

    print(f"Class Probabilities: {pred}")
    print(f"Predicted Class: {class_name}")

    if class_name in ['porn', 'hentai', 'sexy']:
        print("🚨 NSFW Image")
    else:
        print("✅ Safe Image")

# %%
check_image(r"C:\Users\HABEN\Downloads\images (2).jpg")
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 check_image(r"C:\Users\HABEN\Downloads\images (2).jpg")
#
# Cell In[2], line 7, in check_image(img_path)
#       4 def check_image(img_path):
#       6     img = cv2.imread(img_path)
# ----> 7     img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#       9     img = cv2.resize(img, (224, 224))
#      11     img = img.astype(np.float32) / 255.0
#
# error: OpenCV(4.13.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\color.cpp:199: error: (-215:Assertion failed) !_src.empty() in function 'cv::cvtColor'
